# %% [markdown]
# ## Mini project [행맨 게임 제작]
#
# 안녕하세요.
# 수강생 여러분~! Chapter 1 ~ 6 까지의 수업은 잘 들으셨나요?
#
# 여러분의 모든 역량을 총 동원해 문제를 풀어주셨합니다.
#
#
#
# #### 과제 설명
#
# 이번 개발 주제는 '행맨' 게임이구요.
#
# 행맨 게임은 아주 유명한 단어 퀴즈 프로그램이예요
#
# 어떤 단어가 주어지면 그 단어의 길이만큼 빈 칸(밑줄) 이 주어지고
# 플레이어는 알파벳을 하나씩 얘기하면서 단어를 추측해요!
#
# 10번만에 맞히지 못하면 게임이 끝납니다. 🥲

# %% [markdown]
# #### 예시를 들어볼께요!!
#
# 만약 E 가 단어에 포함돼있다면, 해당하는 위치에 E 를 표시해줍니다
#
# _ _ _ _ E E
# 이렇게 되겠네요.
#
# 이번에는 A를 해볼께요
# A 는 포함되지 않으므로 기회가 줄어들고 지금까지 맞힌 내용 그대로 출력합니다.
#
# _ _ _ _ E E
# 변화가 없지요.
#
# 이번에는 C 를 해봅시다.
#
# 그럼
# C _ _ _ E E
#
# 다음에는 F 를
# C _ F F E E
#
# 마지막으로 O 를 해보면
# C O F F E E 로 게임은 성공으로 끝나게 됩니다.

# %% [markdown]
# ##본격적인 행맨 게임 규칙 설명
#
# - words 리스트에 추가된 단어들을 사용해주세요
#   - words = ["apple", "banana", "orange", "grape", "lemon"]
#
# - 단어의 길이에 맞게 밑줄을 출력해주세요
#   (예)banana의 경우 _ _ _ _ _ _
#
# - 사용자부터 1글자씩 입력을 받되,
#    - 단어에 입력값이 포함되면 "단어를 맞추셨군요. 더 힘내봐요"라고 출력해주세요"
#    - 단어에 입력값이 포함되어 있지 않다면 "틀렸습니다. 남은 시도 횟수 "란 메시지와 함꼐 남은 횟수를 출력해주세요
#
# - 매번 입력을 받을 때마다 현재까지 맞힌 글자들 표시(맞히면 글자는 밑줄 출력)
#     - 예) a 입력 시 : a _ _ _ _
#           p 입력 시 : a p p _ _
#           c 입력 시 : a p p _ _
#
# - 모든 단어를 맞췄을 경우 "축하합니다! 단어를 맞추셨습니다"와 시도 횟수를 출력해주세요
#
#
# 행맨은 정말 유명 게임으로 찾아볼 수 있는 자료들이 많습니다.
# 문제가 어려우신 경우 구글링 통해 문제를 해결해보세요.

# %%
import random

# 게임에 사용될 단어 목록
words = ["apple", "banana", "orange", "grape", "lemon"]

# 행맨 그림
hangman_pics = [
    """
     ------
     |    |
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |    |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\\
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\\
     |   /
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\\
     |   / \\
     |
    ---""",
]


class HangmanGame:
    def __init__(self):
        self.word_index = 0
        self.word = words[self.word_index]
        self.hint = ["_"] * len(self.word)
        self.chance = 6
        self.used_letters = set()

    def display(self):
        print(hangman_pics[6 - self.chance])
        print("현재까지 맞힌 글자: ", " ".join(self.hint))
        print("사용한 글자: ", ", ".join(sorted(self.used_letters)))
        print(f"남은 시도 횟수: {self.chance}\n")

    def play(self):
        while self.chance > 0:
            self.display()
            guess = input("알파벳을 입력하세요: ").lower()

            if len(guess) != 1 or not guess.isalpha():
                print("유효한 알파벳 한 글자를 입력하세요.\n")
                continue

            if guess in self.used_letters:
                print("이미 사용한 글자입니다. 다른 글자를 선택하세요.\n")
                continue

            self.used_letters.add(guess)

            if guess in self.word:
                print("단어를 맞추셨군요. 더 힘내봐요!\n")
                for i, letter in enumerate(self.word):
                    if letter == guess:
                        self.hint[i] = guess

                if "_" not in self.hint:
                    print(f"축하합니다! 단어를 맞추셨습니다: {self.word}\n")
                    if self.word_index == len(words) - 1:
                        print("모든 단어를 맞추셨습니다. 게임을 종료합니다.")
                        return
                    else:
                        self.word_index += 1
                        self.word = words[self.word_index]
                        self.hint = ["_"] * len(self.word)
                        self.chance = 6
                        self.used_letters = set()
                        print("새로운 단어로 게임이 계속됩니다!\n")
            else:
                self.chance -= 1
                print(f"틀렸습니다. 남은 시도 횟수: {self.chance}\n")

        print(hangman_pics[-1])
        print(f"게임 오버! 정답은 {self.word}였습니다.\n")
        if self.word_index == len(words) - 1:
            print("모든 단어를 맞추지 못했습니다. 게임을 종료합니다.")
        else:
            print("새로운 단어로 게임이 계속됩니다!\n")
            self.word_index += 1
            self.word = words[self.word_index]
            self.hint = ["_"] * len(self.word)
            self.chance = 6
            self.used_letters = set()
            self.play()


if __name__ == "__main__":
    game = HangmanGame()
    game.play()
# Out:
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  _ _ _ _ _
# 사용한 글자:
# 남은 시도 횟수: 6
#
# 단어를 맞추셨군요. 더 힘내봐요!
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  a _ _ _ _
# 사용한 글자:  a
# 남은 시도 횟수: 6
#
# 단어를 맞추셨군요. 더 힘내봐요!
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  a p p _ _
# 사용한 글자:  a, p
# 남은 시도 횟수: 6
#
# 단어를 맞추셨군요. 더 힘내봐요!
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  a p p l _
# 사용한 글자:  a, l, p
# 남은 시도 횟수: 6
#
# 단어를 맞추셨군요. 더 힘내봐요!
#
# 축하합니다! 단어를 맞추셨습니다: apple
#
# 새로운 단어로 게임이 계속됩니다!
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  _ _ _ _ _ _
# 사용한 글자:
# 남은 시도 횟수: 6
#
# 유효한 알파벳 한 글자를 입력하세요.
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  _ _ _ _ _ _
# 사용한 글자:
# 남은 시도 횟수: 6
#
# 유효한 알파벳 한 글자를 입력하세요.
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  _ _ _ _ _ _
# 사용한 글자:
# 남은 시도 횟수: 6
#
# 유효한 알파벳 한 글자를 입력하세요.
#
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 현재까지 맞힌 글자:  _ _ _ _ _ _
# 사용한 글자:
# 남은 시도 횟수: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23692\3367561174.py in <module>
#     132 if __name__ == "__main__":
#     133     game = HangmanGame()
# --> 134     game.play()
#
# ~\AppData\Local\Temp\ipykernel_23692\3367561174.py in play(self)
#      82         while self.chance > 0:
#      83             self.display()
# ---> 84             guess = input("알파벳을 입력하세요: ").lower()
#      85
#      86             if len(guess) != 1 or not guess.isalpha():
#
# c:\Users\dhg12\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# c:\Users\dhg12\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
